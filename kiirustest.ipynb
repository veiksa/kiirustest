# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
import pylab
#import veikoscripts as vs
from ggplot import *
from decimal import *
from altair import *
from datetime import datetime, timedelta

# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib
# /home/manager/anaconda2/lib/python2.7/site-packages/IPython/core/magics/pylab.py:161: UserWarning: pylab import has clobbered these variables: ['xlim', 'Text', 'pylab', 'datetime', 'colors', 'ylim', 'legend']
# `%matplotlib` prevents importing * from pylab and numpy
#   "\n`%matplotlib` prevents importing * from pylab and numpy"

# %%
kiirustest = pd.read_csv('/home/manager/bitbucket/60m/kiirustest.csv', header=0, sep=',', na_values='#VALUE!', na_filter=True)

# %%
figure = ggplot(kiirustest, aes('Aasta', 'Aeg(sekundites)', color='Nimi')) + geom_point(size=60) +\
    geom_line() + ggtitle('Peresisene 60m jooksuvoistlus') +\
    scale_y_continuous(limits=[50.0, 0.0]) + scale_x_continuous(breaks=[2017],labels=["2017"])
print figure
# Out:
# <ggplot: (8762612930637)>
